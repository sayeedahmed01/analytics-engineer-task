# %%
import pandas as pd
from pathlib import Path
import json
pd.set_option('display.max_rows', 100)

# %% [markdown]
# ### Setting up the file paths

# %%
base_dir = Path().resolve().parent

brands_file = base_dir / 'data' / 'brands.json'
users_file = base_dir / 'data' / 'users.json'
receipts_file = base_dir / 'data' / 'receipts.json'

# %% [markdown]
# ### Function to read a JSON file into a python object

# %%
def read_json_lines(file_path):
    data = []
    with open(file_path, 'r') as file:
        for line in file:
            data.append(json.loads(line))
    return data

# %%
brands_data = read_json_lines(brands_file)
users_data = read_json_lines(users_file)
receipts_data = read_json_lines(receipts_file)

# %% [markdown]
# ### Created function to perform common operations

# %%
def flatten_and_normalize(data, record_path=None, meta=None):
    return pd.json_normalize(data, record_path, meta, sep='_')

def reorder_and_rename_columns(df, order, column_mapping):
    df = df[order]
    df = df.rename(columns=column_mapping)
    return df

def convert_to_datetime(df, date_columns):
    for col in date_columns:
        df[col] = pd.to_datetime(df[col], unit='ms')
    return df

# %% [markdown]
# ### Converting JSON's into Pandas DataFrames for futher analysis and transformations

# %% [markdown]
# #### Brands Data

# %%
brands_df = flatten_and_normalize(brands_data)

brands_order = [
    '_id_$oid', 'name', 'brandCode', 'barcode', 'category', 'categoryCode', 'topBrand', 'cpg_$id_$oid', 'cpg_$ref' 
]

brands_column_mapping = {
    '_id_$oid': 'brand_id',
    'barcode': 'barcode',
    'category': 'category',
    'categoryCode': 'category_code',
    'cpg_$id_$oid': 'cpg_id',
    'cpg_$ref': 'cpg_ref',
    'name': 'brand_name',
    'topBrand': 'top_brand',
    'brandCode': 'brand_code'
}

brands_df = reorder_and_rename_columns(brands_df, brands_order, brands_column_mapping)
print("No. of records: ",  len(brands_df))
brands_df.head()
# Out:
# No. of records:  1167
#                    brand_id                 brand_name  \
# 0  601ac115be37ce2ead437551  test brand @1612366101024
# 1  601c5460be37ce2ead43755f                  Starbucks
# 2  601ac142be37ce2ead43755d  test brand @1612366146176
# 3  601ac142be37ce2ead43755a  test brand @1612366146051
# 4  601ac142be37ce2ead43755e  test brand @1612366146827
#
#                       brand_code       barcode        category  \
# 0                            NaN  511111019862          Baking
# 1                      STARBUCKS  511111519928       Beverages
# 2  TEST BRANDCODE @1612366146176  511111819905          Baking
# 3  TEST BRANDCODE @1612366146051  511111519874          Baking
# 4  TEST BRANDCODE @1612366146827  511111319917  Candy & Sweets
#
#       category_code top_brand                    cpg_id cpg_ref
# 0            BAKING     False  601ac114be37ce2ead437550    Cogs
# 1         BEVERAGES     False  5332f5fbe4b03c9a25efd0ba    Cogs
# 2            BAKING     False  601ac142be37ce2ead437559    Cogs
# 3            BAKING     False  601ac142be37ce2ead437559    Cogs
# 4  CANDY_AND_SWEETS     False  5332fa12e4b03c9a25efd1e7    Cogs

# %% [markdown]
# #### Users Data

# %%
users_df = flatten_and_normalize(users_data)

users_order = [
    '_id_$oid', 'role', 'signUpSource', 'state', 'createdDate_$date', 'active', 'lastLogin_$date' 
]

users_column_mapping = {
    '_id_$oid': 'user_id',
    'active': 'active',
    'createdDate_$date': 'created_date',
    'lastLogin_$date': 'last_login',
    'role': 'role',
    'signUpSource': 'sign_up_source',
    'state': 'state'
}

users_df = reorder_and_rename_columns(users_df, users_order, users_column_mapping)
users_df = convert_to_datetime(users_df, ['created_date', 'last_login'])

print("No. of records: ",  len(users_df))
users_df.head()
# Out:
# No. of records:  495
#                     user_id      role sign_up_source state  \
# 0  5ff1e194b6a9d73a3a9f1052  consumer          Email    WI
# 1  5ff1e194b6a9d73a3a9f1052  consumer          Email    WI
# 2  5ff1e194b6a9d73a3a9f1052  consumer          Email    WI
# 3  5ff1e1eacfcf6c399c274ae6  consumer          Email    WI
# 4  5ff1e194b6a9d73a3a9f1052  consumer          Email    WI
#
#              created_date  active                    last_login
# 0 2021-01-03 15:24:04.800    True 2021-01-03 15:25:37.857999872
# 1 2021-01-03 15:24:04.800    True 2021-01-03 15:25:37.857999872
# 2 2021-01-03 15:24:04.800    True 2021-01-03 15:25:37.857999872
# 3 2021-01-03 15:25:30.554    True 2021-01-03 15:25:30.596999936
# 4 2021-01-03 15:24:04.800    True 2021-01-03 15:25:37.857999872

# %% [markdown]
# #### Receipts Data

# %%
receipts_df = flatten_and_normalize(receipts_data)

receipts_order = [
    '_id_$oid', 'userId', 'bonusPointsEarned', 'bonusPointsEarnedReason', 'createDate_$date', 
    'dateScanned_$date', 'finishedDate_$date', 'modifyDate_$date', 'pointsAwardedDate_$date', 
    'pointsEarned', 'purchaseDate_$date', 'purchasedItemCount', 'rewardsReceiptStatus', 'totalSpent'
]

receipts_column_mapping = {
    '_id_$oid': 'receipt_id',
    'userId': 'user_id',
    'bonusPointsEarned': 'bonus_points_earned',
    'bonusPointsEarnedReason': 'bonus_points_earned_reason',
    'createDate_$date': 'create_date',
    'dateScanned_$date': 'date_scanned',
    'finishedDate_$date': 'finished_date',
    'modifyDate_$date': 'modify_date',
    'pointsAwardedDate_$date': 'points_awarded_date',
    'pointsEarned': 'points_earned',
    'purchaseDate_$date': 'purchase_date',
    'purchasedItemCount': 'purchased_item_count',
    'rewardsReceiptStatus': 'rewards_receipt_status',
    'totalSpent': 'total_spent'
}

receipts_only_df = reorder_and_rename_columns(receipts_df, receipts_order, receipts_column_mapping)

receipts_only_df = convert_to_datetime(receipts_only_df, [
    'create_date', 'date_scanned', 'finished_date', 'modify_date', 'points_awarded_date', 'purchase_date'
])

receipts_only_df.head()
# Out:
#                  receipt_id                   user_id  bonus_points_earned  \
# 0  5ff1e1eb0a720f0523000575  5ff1e1eacfcf6c399c274ae6                500.0
# 1  5ff1e1bb0a720f052300056b  5ff1e194b6a9d73a3a9f1052                150.0
# 2  5ff1e1f10a720f052300057a  5ff1e1f1cfcf6c399c274b0b                  5.0
# 3  5ff1e1ee0a7214ada100056f  5ff1e1eacfcf6c399c274ae6                  5.0
# 4  5ff1e1d20a7214ada1000561  5ff1e194b6a9d73a3a9f1052                  5.0
#
#                           bonus_points_earned_reason         create_date  \
# 0  Receipt number 2 completed, bonus point schedu... 2021-01-03 15:25:31
# 1  Receipt number 5 completed, bonus point schedu... 2021-01-03 15:24:43
# 2                         All-receipts receipt bonus 2021-01-03 15:25:37
# 3                         All-receipts receipt bonus 2021-01-03 15:25:34
# 4                         All-receipts receipt bonus 2021-01-03 15:25:06
#
#          date_scanned       finished_date         modify_date  \
# 0 2021-01-03 15:25:31 2021-01-03 15:25:31 2021-01-03 15:25:36
# 1 2021-01-03 15:24:43 2021-01-03 15:24:43 2021-01-03 15:24:48
# 2 2021-01-03 15:25:37                 NaT 2021-01-03 15:25:42
# 3 2021-01-03 15:25:34 2021-01-03 15:25:34 2021-01-03 15:25:39
# 4 2021-01-03 15:25:06 2021-01-03 15:25:11 2021-01-03 15:25:11
#
#   points_awarded_date points_earned       purchase_date  purchased_item_count  \
# 0 2021-01-03 15:25:31         500.0 2021-01-03 00:00:00                   5.0
# 1 2021-01-03 15:24:43         150.0 2021-01-02 15:24:43                   2.0
# 2                 NaT             5 2021-01-03 00:00:00                   1.0
# 3 2021-01-03 15:25:34           5.0 2021-01-03 00:00:00                   4.0
# 4 2021-01-03 15:25:06           5.0 2021-01-02 15:25:06                   2.0
#
#   rewards_receipt_status total_spent
# 0               FINISHED       26.00
# 1               FINISHED       11.00
# 2               REJECTED       10.00
# 3               FINISHED       28.00
# 4               FINISHED        1.00

# %% [markdown]
# ### Using the rewardsReceiptItemList to create a seperate df for the items in each receipt to enable access to the granular data

# %%
for receipt in receipts_data:
    receipt['id'] = receipt['_id']['$oid']
    if 'rewardsReceiptItemList' not in receipt:
        receipt['rewardsReceiptItemList'] = []
    for item in receipt['rewardsReceiptItemList']:
        item['receipt_id'] = receipt['id']
        
# Normalize the data to extract rewardsReceiptItemList and associated _id
items_df = flatten_and_normalize(
    receipts_data,
    record_path=['rewardsReceiptItemList'],
    meta=['id']
)

items_df.drop('id', inplace=True, axis=1)
items_df.head()
# Out:
#         barcode                                        description finalPrice  \
# 0          4011                                     ITEM NOT FOUND      26.00
# 1          4011                                     ITEM NOT FOUND          1
# 2  028400642255  DORITOS TORTILLA CHIP SPICY SWEET CHILI REDUCE...      10.00
# 3           NaN                                                NaN        NaN
# 4          4011                                     ITEM NOT FOUND      28.00
#
#   itemPrice needsFetchReview partnerItemId preventTargetGapPoints  \
# 0     26.00            False             1                   True
# 1         1              NaN             1                    NaN
# 2     10.00             True             2                   True
# 3       NaN            False             1                   True
# 4     28.00            False             1                   True
#
#    quantityPurchased userFlaggedBarcode userFlaggedNewItem  ... itemNumber  \
# 0                5.0               4011               True  ...        NaN
# 1                1.0                NaN                NaN  ...        NaN
# 2                1.0       028400642255               True  ...        NaN
# 3                NaN               4011               True  ...        NaN
# 4                4.0               4011               True  ...        NaN
#
#    originalMetaBriteQuantityPurchased pointsEarned targetPrice  \
# 0                                 NaN          NaN         NaN
# 1                                 NaN          NaN         NaN
# 2                                 NaN          NaN         NaN
# 3                                 NaN          NaN         NaN
# 4                                 NaN          NaN         NaN
#
#   competitiveProduct originalFinalPrice originalMetaBriteItemPrice deleted  \
# 0                NaN                NaN                        NaN     NaN
# 1                NaN                NaN                        NaN     NaN
# 2                NaN                NaN                        NaN     NaN
# 3                NaN                NaN                        NaN     NaN
# 4                NaN                NaN                        NaN     NaN
#
#   priceAfterCoupon metabriteCampaignId
# 0              NaN                 NaN
# 1              NaN                 NaN
# 2              NaN                 NaN
# 3              NaN                 NaN
# 4              NaN                 NaN
#
# [5 rows x 35 columns]

# %%
items_df.columns
# Out:
# Index(['barcode', 'description', 'finalPrice', 'itemPrice', 'needsFetchReview',
#        'partnerItemId', 'preventTargetGapPoints', 'quantityPurchased',
#        'userFlaggedBarcode', 'userFlaggedNewItem', 'userFlaggedPrice',
#        'userFlaggedQuantity', 'receipt_id', 'needsFetchReviewReason',
#        'pointsNotAwardedReason', 'pointsPayerId', 'rewardsGroup',
#        'rewardsProductPartnerId', 'userFlaggedDescription',
#        'originalMetaBriteBarcode', 'originalMetaBriteDescription', 'brandCode',
#        'competitorRewardsGroup', 'discountedItemPrice',
#        'originalReceiptItemText', 'itemNumber',
#        'originalMetaBriteQuantityPurchased', 'pointsEarned', 'targetPrice',
#        'competitiveProduct', 'originalFinalPrice',
#        'originalMetaBriteItemPrice', 'deleted', 'priceAfterCoupon',
#        'metabriteCampaignId'],
#       dtype='object')

# %% [markdown]
# ## Data Quality Checks:

# %% [markdown]
# Based on the data I have previewed so far, I have carried out relevant data quality checks based on intuition. These checks can be further expanded and refined based on business logic and other expected characteristics

# %% [markdown]
# ### User data checks

# %% [markdown]
# For the Users data the main goal was to ensure intergrity of the data and check for duplication

# %%
users_df.isna().sum()
# Out:
# user_id            0
# role               0
# sign_up_source    48
# state             56
# created_date       0
# active             0
# last_login        62
# dtype: int64

# %%
print(users_df.dtypes)
# Out:
# user_id                   object
# role                      object
# sign_up_source            object
# state                     object
# created_date      datetime64[ns]
# active                      bool
# last_login        datetime64[ns]
# dtype: object

# %% [markdown]
# #### Checking for duplicate records
# Based on the checks below there seems to be a significant amount of duplication in the user_id column which is important in a Relational DB to conform to the Consistency property in ACID.

# %%
user_duplicate_record = users_df[users_df.duplicated('user_id')]

print("Duplicated Records:")
user_duplicate_record.head(70)
# Out:
# Duplicated Records:
#                       user_id      role sign_up_source state  \
# 1    5ff1e194b6a9d73a3a9f1052  consumer          Email    WI
# 2    5ff1e194b6a9d73a3a9f1052  consumer          Email    WI
# 4    5ff1e194b6a9d73a3a9f1052  consumer          Email    WI
# 5    5ff1e194b6a9d73a3a9f1052  consumer          Email    WI
# 8    5ff1e194b6a9d73a3a9f1052  consumer          Email    WI
# 10   5ff1e194b6a9d73a3a9f1052  consumer          Email    WI
# 11   5ff1e1eacfcf6c399c274ae6  consumer          Email    WI
# 12   5ff1e194b6a9d73a3a9f1052  consumer          Email    WI
# 13   5ff1e1eacfcf6c399c274ae6  consumer          Email    WI
# 14   5ff1e194b6a9d73a3a9f1052  consumer          Email    WI
# 15   5ff1e194b6a9d73a3a9f1052  consumer          Email    WI
# 18   5ff1e1eacfcf6c399c274ae6  consumer          Email    WI
# 19   5ff1e194b6a9d73a3a9f1052  consumer          Email    WI
# 24   5ff370c562fde912123a5e0e  consumer          Email    WI
# 26   5ff36d0362fde912123a5535  consumer          Email    WI
# 27   5ff36be7135e7011bcb856d3  consumer          Email    WI
# 29   5ff36d0362fde912123a5535  consumer          Email    WI
# 31   5ff36a3862fde912123a4460  consumer          Email    WI
# 32   5ff370c562fde912123a5e0e  consumer          Email    WI
# 33   5ff36a3862fde912123a4460  consumer          Email    WI
# 34   5ff36a3862fde912123a4460  consumer          Email    WI
# 35   5ff370c562fde912123a5e0e  consumer          Email    WI
# 36   5ff36a3862fde912123a4460  consumer          Email    WI
# 37   5ff370c562fde912123a5e0e  consumer          Email    WI
# 39   5ff36be7135e7011bcb856d3  consumer          Email    WI
# 43   5ff47392c3d63511e2a47881  consumer          Email    WI
# 44   5ff4ce33c3d63511e2a484b6  consumer          Email    WI
# 46   5ff47392c3d63511e2a47881  consumer          Email    WI
# 48   5ff4ce33c3d63511e2a484b6  consumer          Email    WI
# %%
user_id_to_check = '5a43c08fe4b014fd6b6a0612'

# Extract JSON data for the specific user_id
json_data_for_user = [user for user in users_data if user['_id']['$oid'] == user_id_to_check]

print("JSON Data for user_id:", user_id_to_check)
print(json.dumps(json_data_for_user, indent=4))

df_data_for_user = users_df[users_df['user_id'] == user_id_to_check]

print("DataFrame Data for user_id:", user_id_to_check)
df_data_for_user
# Out:
# JSON Data for user_id: 5a43c08fe4b014fd6b6a0612
# [
#     {
#         "_id": {
#             "$oid": "5a43c08fe4b014fd6b6a0612"
#         },
#         "active": true,
#         "createdDate": {
#             "$date": 1514389647059
#         },
#         "lastLogin": {
#             "$date": 1613146957155
#         },
#         "role": "consumer"
#     },
#     {
#         "_id": {
#             "$oid": "5a43c08fe4b014fd6b6a0612"
#         },
#         "active": true,
#         "createdDate": {
#             "$date": 1514389647059
#         },
#         "lastLogin": {
#             "$date": 1613146957155
#         },
#         "role": "consumer"
#     },
#     {
#         "_id": {
#             "$oid": "5a43c08fe4b014fd6b6a0612"
#         },
#         "active": true,
#         "createdDate": {
#             "$date": 1514389647059
#         },
#         "lastLogin": {
#             "$date": 1613146957155
#         },
#         "role": "consumer"
#     },
#     {
#         "_id": {
#             "$oid": "5a43c08fe4b014fd6b6a0612"
#         },
#         "active": true,
#         "createdDate": {
#             "$date": 1514389647059
#         },
#         "lastLogin": {
#             "$date": 1613146957155
#         },
#         "role": "consumer"
#     },
#     {
#         "_id": {
#             "$oid": "5a43c08fe4b014fd6b6a0612"
#         },
#         "active": true,
#         "createdDate": {
#             "$date": 1514389647059
#         },
#         "lastLogin": {
#             "$date": 1613146957155
#         },
#         "role": "consumer"
#     },
#     {
#         "_id": {
#             "$oid": "5a43c08fe4b014fd6b6a0612"
#         },
#         "active": true,
#         "createdDate": {
#             "$date": 1514389647059
#         },
#         "lastLogin": {
#             "$date": 1613146957155
#         },
#         "role": "consumer"
#     },
#     {
#         "_id": {
#             "$oid": "5a43c08fe4b014fd6b6a0612"
#         },
#         "active": true,
#         "createdDate": {
#             "$date": 1514389647059
#         },
#         "lastLogin": {
#             "$date": 1613146957155
#         },
#         "role": "consumer"
#     },
#     {
#         "_id": {
#             "$oid": "5a43c08fe4b014fd6b6a0612"
#         },
#         "active": true,
#         "createdDate": {
#             "$date": 1514389647059
#         },
#         "lastLogin": {
#             "$date": 1613146957155
#         },
#         "role": "consumer"
#     }
# ]
# DataFrame Data for user_id: 5a43c08fe4b014fd6b6a0612
#                       user_id      role sign_up_source state  \
# 422  5a43c08fe4b014fd6b6a0612  consumer            NaN   NaN
# 423  5a43c08fe4b014fd6b6a0612  consumer            NaN   NaN
# 424  5a43c08fe4b014fd6b6a0612  consumer            NaN   NaN
# 425  5a43c08fe4b014fd6b6a0612  consumer            NaN   NaN
# 426  5a43c08fe4b014fd6b6a0612  consumer            NaN   NaN
# 428  5a43c08fe4b014fd6b6a0612  consumer            NaN   NaN
# 430  5a43c08fe4b014fd6b6a0612  consumer            NaN   NaN
# 431  5a43c08fe4b014fd6b6a0612  consumer            NaN   NaN
#
#                created_date  active                    last_login
# 422 2017-12-27 15:47:27.059    True 2021-02-12 16:22:37.155000064
# 423 2017-12-27 15:47:27.059    True 2021-02-12 16:22:37.155000064
# 424 2017-12-27 15:47:27.059    True 2021-02-12 16:22:37.155000064
# 425 2017-12-27 15:47:27.059    True 2021-02-12 16:22:37.155000064
# 426 2017-12-27 15:47:27.059    True 2021-02-12 16:22:37.155000064
# 428 2017-12-27 15:47:27.059    True 2021-02-12 16:22:37.155000064
# 430 2017-12-27 15:47:27.059    True 2021-02-12 16:22:37.155000064
# 431 2017-12-27 15:47:27.059    True 2021-02-12 16:22:37.155000064

# %% [markdown]
# #### Group by 'user_id' and check if all the rows are the same

# %%
grouped = user_duplicate_record.groupby('user_id').apply(lambda x: x.nunique() == 1)

grouped
# Out:
#                           user_id  role  sign_up_source  state  created_date  \
# user_id
# 54943462e4b07e684157a532     True  True           False  False          True
# 59c124bae4b0299e55b0f330     True  True           False   True          True
# 5a43c08fe4b014fd6b6a0612     True  True           False  False          True
# 5fa41775898c7a11a6bcef3e     True  True            True  False          True
# 5fb0a078be5fc9775c1f3945     True  True            True   True          True
# 5fbc35711d967d1222cbfefc     True  True            True  False          True
# 5fc961c3b8cfca11a077dd33     True  True            True   True          True
# 5ff1e194b6a9d73a3a9f1052     True  True            True   True          True
# 5ff1e1eacfcf6c399c274ae6     True  True            True   True          True
# 5ff36a3862fde912123a4460     True  True            True   True          True
# 5ff36be7135e7011bcb856d3     True  True            True   True          True
# 5ff36d0362fde912123a5535     True  True            True   True          True
# 5ff370c562fde912123a5e0e     True  True            True   True          True
# 5ff47392c3d63511e2a47881     True  True            True   True          True
# 5ff4ce33c3d63511e2a484b6     True  True            True   True          True
# 5ff4ce3dc3d63511e2a484dc     True  True            True   True          True
# 5ff5d15aeb7c7d12096d91a2     True  True            True   True          True
# 5ff7264e8f142f11dd189504     True  True            True   True          True
# 5ff7268eeb7c7d12096da2a9     True  True            True   True          True
# 5ff73b90eb7c7d31ca8a452b     True  True            True   True          True
# 5ff7930fb3348b11c93372a6     True  True            True   True          True
# 5ff873d1b3348b11c9337716     True  True            True   True          True
# 5ff873ddb3348b11c9337733     True  True            True   True          True
# 5ff8ce8504929111f6e913cb     True  True            True   True          True
# 5ff8da28b3348b11c9337ac6     True  True            True   True          True
# 5ffc8f9704929111f6e922bf     True  True            True   True          True
# 5ffc8ff9b3348b11c9338896     True  True            True   True          True
# 5ffc9d87b3348b11c9338920     True  True            True   True          True
# 5ffcb47d04929111f6e9256c     True  True            True   True          True
# 5ffcb4bc04929111f6e92608     True  True            True   True          True
# 5ffe115404929101d0aaebb2     True  True            True   True          True
# 5fff0f4fb3348b03eb45abb0     True  True            True   True          True
# 5fff4beedf9ace121f0c17ea     True  True            True   True          True
# 5fff55dabd4dff11dda8f5f1     True  True            True   True          True
# 600056a3f7e5b011fce897b0     True  True            True   True          True
# 60005709bd4dff11dda90ac1     True  True            True   True          True
# 6000b75bbe5fc96dfee1d4d3     True  True            True   True          True
# 6000b7aefb296c121a8198b1     True  True            True   True          True
# 6000d46cfb296c121a81b20c     True  True            True   True          True
# 6002541ae257124ec6b99a3a     True  True            True   True          True
# 60025c65fb296c4ef805d9e6     True  True            True   True          True
# 600741d06e6469120a787853     True  True            True   True          True
# 6007464b6e64691717e8c1f0     True  True            True   True          True
# 600748196e64691717e8d4f0     True  True            True   True          True
# 60074b49325c8a1794623876     True  True            True   True          True
# 6008893b633aab121bb8e0a9     True  True            True   True          True
# 60088d55633aab121bb8e41a     True  True            True   True          True
# 600987d77d983a11f63cfa92     True  True            True   True          True
# 6009e60450b3311194385009     True  True            True   True          True
# 600ed42e43298911ce45d1fa     True  True            True   True          True
# 600f008f4329897eac237bd8     True  True            True   True          True
# 600f00d05edb787dce05fb84     True  True            True   True          True
# 600f41b2bd196811e68ea219     True  True            True   True          True
# 600f47f06fd0dc1768a34a12     True  True            True   True          True
# 600fb1ac73c60b12049027bb     True  True            True   True          True
# 6010bddaa4b74c120bd19dfb     True  True            True   True          True
# 60118bcfa4b74c18d3a8c0d7     True  True            True   True          True
# 6011f31ea4b74c18d3a8c476     True  True            True   True          True
# 6011f33173c60b1804ce1102     True  True            True   True          True
# 60132acb73c60b3ca7f3ba32     True  True            True   True          True
# 6014558767804a1228b20d00     True  True            True   True          True
# 60145a3c84231211ce796c5d     True  True            True   True          True
# 60145ff384231211ce796d51     True  True            True  False          True
# 60147d2ac8b50e11d8453f53     True  True            True   True          True
# 60183090c8b50e11d84549c0     True  True            True   True          True
# 60186237c8b50e11d8454d5f     True  True            True  False          True
# 60189c74c8b50e11d8454eff     True  True            True   True          True
# 60189c94c8b50e11d8454f6b     True  True            True   True          True
# 601c2c05969c0b11f7d0b097     True  True            True   True          True
# 60229990b57b8a12187fe9e0     True  True            True   True          True
#
#                           active  last_login
# user_id
# 54943462e4b07e684157a532    True        True
# 59c124bae4b0299e55b0f330    True        True
# 5a43c08fe4b014fd6b6a0612    True        True
# 5fa41775898c7a11a6bcef3e    True        True
# 5fb0a078be5fc9775c1f3945    True       False
# 5fbc35711d967d1222cbfefc    True        True
# 5fc961c3b8cfca11a077dd33    True        True
# 5ff1e194b6a9d73a3a9f1052    True        True
# 5ff1e1eacfcf6c399c274ae6    True        True
# 5ff36a3862fde912123a4460    True        True
# 5ff36be7135e7011bcb856d3    True        True
# 5ff36d0362fde912123a5535    True        True
# 5ff370c562fde912123a5e0e    True        True
# 5ff47392c3d63511e2a47881    True        True
# 5ff4ce33c3d63511e2a484b6    True        True
# 5ff4ce3dc3d63511e2a484dc    True        True
# 5ff5d15aeb7c7d12096d91a2    True        True
# 5ff7264e8f142f11dd189504    True        True
# 5ff7268eeb7c7d12096da2a9    True        True
# 5ff73b90eb7c7d31ca8a452b    True        True
# 5ff7930fb3348b11c93372a6    True        True
# 5ff873d1b3348b11c9337716    True        True
# 5ff873ddb3348b11c9337733    True        True
# 5ff8ce8504929111f6e913cb    True        True
# 5ff8da28b3348b11c9337ac6    True        True
# 5ffc8f9704929111f6e922bf    True        True
# 5ffc8ff9b3348b11c9338896    True        True
# 5ffc9d87b3348b11c9338920    True        True
# 5ffcb47d04929111f6e9256c    True        True
# 5ffcb4bc04929111f6e92608    True        True
# 5ffe115404929101d0aaebb2    True       False
# 5fff0f4fb3348b03eb45abb0    True        True
# 5fff4beedf9ace121f0c17ea    True        True
# 5fff55dabd4dff11dda8f5f1    True        True
# 600056a3f7e5b011fce897b0    True        True
# 60005709bd4dff11dda90ac1    True        True
# 6000b75bbe5fc96dfee1d4d3    True       False
# 6000b7aefb296c121a8198b1    True        True
# 6000d46cfb296c121a81b20c    True        True
# 6002541ae257124ec6b99a3a    True       False
# 60025c65fb296c4ef805d9e6    True       False
# 600741d06e6469120a787853    True        True
# 6007464b6e64691717e8c1f0    True        True
# 600748196e64691717e8d4f0    True        True
# 60074b49325c8a1794623876    True        True
# 6008893b633aab121bb8e0a9    True        True
# 60088d55633aab121bb8e41a    True        True
# 600987d77d983a11f63cfa92    True        True
# 6009e60450b3311194385009    True       False
# 600ed42e43298911ce45d1fa    True        True
# 600f008f4329897eac237bd8    True        True
# 600f00d05edb787dce05fb84    True       False
# 600f41b2bd196811e68ea219    True        True
# 600f47f06fd0dc1768a34a12    True        True
# 600fb1ac73c60b12049027bb    True        True
# 6010bddaa4b74c120bd19dfb    True        True
# 60118bcfa4b74c18d3a8c0d7    True        True
# 6011f31ea4b74c18d3a8c476    True        True
# 6011f33173c60b1804ce1102    True        True
# 60132acb73c60b3ca7f3ba32    True        True
# 6014558767804a1228b20d00    True        True
# 60145a3c84231211ce796c5d    True        True
# 60145ff384231211ce796d51    True       False
# 60147d2ac8b50e11d8453f53    True       False
# 60183090c8b50e11d84549c0    True        True
# 60186237c8b50e11d8454d5f    True       False
# 60189c74c8b50e11d8454eff    True        True
# 60189c94c8b50e11d8454f6b    True        True
# 601c2c05969c0b11f7d0b097    True        True
# 60229990b57b8a12187fe9e0    True        True

# %% [markdown]
# Based on the above result, majority of the rows have the same data duplicated, ideally these can be deduplicated while loading the data into the Database. For the rows that have differening values, they would require further analysis and appropriate business logic to handle them.

# %% [markdown]
# #### Checking for unique values in the 'roles' column

# %% [markdown]
# According to the data dictionary the values should be by default 'consumer' but given the presence of the values 'fetch-staff', there needs to be rules set in place on how to capture those results.

# %%
users_df['role'].unique()
# Out:
# array(['consumer', 'fetch-staff'], dtype=object)

# %% [markdown]
# #### Checking for values in the 'active' column

# %%
users_df['active'].unique()
# Out:
# array([ True, False])

# %% [markdown]
# ### Brand Table data check

# %%
brands_df.isna().sum()
# Out:
# brand_id           0
# brand_name         0
# brand_code       234
# barcode            0
# category         155
# category_code    650
# top_brand        612
# cpg_id             0
# cpg_ref            0
# dtype: int64

# %%
print(brands_df.dtypes)
# Out:
# brand_id         object
# brand_name       object
# brand_code       object
# barcode          object
# category         object
# category_code    object
# top_brand        object
# cpg_id           object
# cpg_ref          object
# dtype: object

# %% [markdown]
# #### Checking for duplicate brand_id

# %%
brand_duplicate_id_counts = brands_df[brands_df.duplicated('brand_id')]

print("Duplicated Records:")
brand_duplicate_id_counts.head(70)
# Out:
# Duplicated Records:
# Empty DataFrame
# Columns: [brand_id, brand_name, brand_code, barcode, category, category_code, top_brand, cpg_id, cpg_ref]
# Index: []

# %% [markdown]
# #### Checking for duplicate brand_code

# %%
brand_duplicate_record = brands_df[brands_df.duplicated('brand_code')]

print("Duplicated Records:")
brand_duplicate_record.head(70)
# Out:
# Duplicated Records:
#                      brand_id                             brand_name  \
# 11   57c08106e4b0718ff5fcb02c                            MorningStar
# 18   5fb28549be37ce522e165cb5              test brand @1605535049181
# 23   5332f5fee4b03c9a25efd0bd                      Bottled Starbucks
# 24   5332fa7ce4b03c9a25efd22e                          Full Throttle
# 25   5e9f18bfbe37ce3e45b6a77f                          PopUp Brand A
# 29   5f4936ddbe37ce52f8314fd9              test brand @1598633693011
# 31   5fd2a0aebe37ce49eb72c0ee              test brand @1607639214411
# 34   5332f772e4b03c9a25efd125                             Gold Medal
# 43   5332f765e4b03c9a25efd11f                   Glaceau vitaminwater
# 46   5332f5f3e4b03c9a25efd0ad                             Gree Giant
# 49   55b630d9e4b0d8e685c1421f                                Sundrop
# 55   5332f6ede4b03c9a25efd0e5                             Blue Bunny
# 56   5332fa05e4b03c9a25efd1d6                                  Krave
# 61   55b630e1e4b0d8e685c14220                           A&W Rootbeer
# 67   5f3e9195be37ce5a0e01b960              test brand @1597936021514
# 74   5332f743e4b03c9a25efd109                                Keebler
# 77   5332fa7ee4b03c9a25efd230                               Powerade
# 80   57ace91ae4b057c992a316ac                      Pizza Pizza Pizza
# 83   5332f5f2e4b03c9a25efd0ab                             Our Family
# 95   5332f9fce4b03c9a25efd1cd                           Honey Smacks
# 98   5f513e9ebe37ce21f1287c00              test brand @1599159966676
# 99   5332f7b8e4b03c9a25efd145                          Stella Artois
# 104  57c0829ce4b0718ff5fcb03a                               Victoria
# 112  5fa98944be37ce239d1070fe              test brand @1604946244133
# 113  5332f9f2e4b03c9a25efd1c8                                Crispix
# 114  55a41b55e4b0d0a65b3692ef                               NessAlla
# 117  55b630c2e4b0d8e685c1421d                                RC Cola
# 118  5332f605e4b03c9a25efd0c0                                    Amp
# 130  5332f9f2e4b03c9a25efd1c7                               All-Bran
# 135  5332f5f5e4b03c9a25efd0b0                          Betty Crocker
# 146  55b6308ee4b0d8e685c1421a                                Snapple
# 147  5332f760e4b03c9a25efd11b                             Honest Ade
# 151  5332f9f3e4b03c9a25efd1c9                              Pop-tarts
# 153  58861c7d4e8d0d20bc42c4d6  Jell-O Refrigerated Pudding & Gelatin
# 154  55b630fde4b0d8e685c14223                        Diet Dr. Pepper
# 159  5fa1c568be37ce402c4618f6              test brand @1604437352935
# 163  57ebc2ace4b0ac389136a346                                     P3
# 167  585a9726e4b03e62d1ce0e95                                   Tazo
# 169  5332f7d3e4b03c9a25efd14e                               Cheez-It
# 170  5f504acabe37ce0b793c9418              test brand @1599097546963
# 172  57c08294e4b0718ff5fcb039                                Jupiler
# 173  5332f77ce4b03c9a25efd12a                             Gardetto's
# 174  5332f9ede4b03c9a25efd1c2                               Danimals
# 179  5ffe3a87be37ce7aab2d4fdb              test brand @1610496647311
# 181  5fff3a7abe37ce2bb793010e              test brand @1610562170795
# 188  58b59989e4b0857c2ddb7255                          Redd's Wicked
# 195  5332fa7ae4b03c9a25efd229                                  Fanta
# 197  5f772951be37ce6b592e90d0              test brand @1601644881253
# 207  5ffe3682be37ce5e01754c55              test brand @1610495618015
# 210  5ffe3480be37ce5e01754c44              test brand @1610495104441
# 212  5ffe35f9be37ce5e01754c4c              test brand @1610495481412
# 215  5ff768e3be37ce1e961f32a0              test brand @1610049763071
# 224  5fd7f2b8be37ce733975586f              test brand @1607987896065
# 227  5332fa7be4b03c9a25efd22b                       Diet Cherry Coke
# 229  5332f775e4b03c9a25efd127                               Cheerios
# 230  581ce962e4b058c71f74c443                                      .
# 231  5332fa08e4b03c9a25efd1d8                         Frosted Flakes
# 233  5f628235be37ce78e6e2efb1              test brand @1600291381675
# 234  58b5988ce4b0857c2ddb7252                 Henry's Hard Sparkling
# 235  5f3ff200be37ce1c81aa1e0b              test brand @1598026240846
# 236  57ebc125e4b0ac389136a33b                Kraft Macaroni & Cheese
# 237  5332f7c8e4b03c9a25efd148                         Cascadian Farm
# 240  5f493665be37ce52f8314fca              test brand @1598633573683
# 245  5d66961cee7f2d201c7281cc                            Test brand1
# 261  5332fa03e4b03c9a25efd1d5                  Fruit Flavored Snacks
# 269  5fcda47cbe37ce688e08b0c3              test brand @1607312508610
# 272  5332fa79e4b03c9a25efd226                            Mello Yello
# 275  552ecca1e4b02ff29f99b215                               Top Care
# 278  585a967fe4b03e62d1ce0e80                    Lay's Kettle Cooked
# 282  5332f608e4b03c9a25efd0c1                            Sierra Mist
#
#     brand_code       barcode           category category_code top_brand  \
# 11         NaN  511111102540                NaN           NaN       NaN
# 18         NaN  511111317364             Baking        BAKING     False
# 23         NaN  511111303947                NaN           NaN       NaN
# 24         NaN  511111802914                NaN           NaN       NaN
# 25         NaN  511111914549             Baking        BAKING       NaN
# 29         NaN  511111315957             Baking        BAKING       NaN
# 31         NaN  511111518112             Baking        BAKING     False
# 34         NaN  511111103653                NaN           NaN       NaN
# 43         NaN  511111503699                NaN           NaN       NaN
# 46         NaN  511111104025                NaN           NaN       NaN
# 49         NaN  511111302629                NaN           NaN       NaN
# 55         NaN  511111603870                NaN           NaN       NaN
# 56         NaN  511111103141                NaN           NaN       NaN
# 61         NaN  511111102618                NaN           NaN       NaN
# 67         NaN  511111615583             Baking        BAKING       NaN
# 74         NaN  511111903789             Snacks           NaN       NaN
# 77         NaN  511111702894                NaN           NaN       NaN
# 80         NaN  511111602552                NaN           NaN       NaN
# 83         NaN  511111604037                NaN           NaN       NaN
# 95         NaN  511111003199                NaN           NaN       NaN
# 98         NaN  511111816492             Baking        BAKING       NaN
# 99         NaN  511111903413                NaN           NaN       NaN
# 104        NaN  511111002437                NaN           NaN       NaN
# 112        NaN  511111217251             Baking        BAKING     False
# 113        NaN  511111803232                NaN           NaN       NaN
# 114        NaN  511111502708                NaN           NaN       NaN
# 117        NaN  511111002642                NaN           NaN       NaN
# 118        NaN  511111403913                NaN           NaN       NaN
# 130        NaN  511111003243                NaN           NaN       NaN
# 135        NaN  511111404002                NaN           NaN       NaN
# 146        NaN  511111202677                NaN           NaN       NaN
# 147        NaN  511111603719                NaN           NaN       NaN
# 151        NaN  511111303220                NaN           NaN       NaN
# 153             511111601449             Snacks           NaN     False
# 154        NaN  511111502586                NaN           NaN       NaN
# 159        NaN  511111717249             Baking        BAKING     False
# 163             511111801962               Deli           NaN     False
# 167        NaN  511111501497          Beverages           NaN       NaN
# 169        NaN  511111803393             Snacks           NaN       NaN
# 170        NaN  511111316480             Baking        BAKING       NaN
# 172        NaN  511111202448                NaN           NaN       NaN
# 173        NaN  511111703617                NaN           NaN       NaN
# 174        NaN  511111403289                NaN           NaN       NaN
# 179        NaN  511111619543             Baking        BAKING     False
# 181        NaN  511111119555             Baking        BAKING     False
# 188             511111400998  Beer Wine Spirits           NaN     False
# 195        NaN  511111402961                NaN           NaN       NaN
# 197        NaN  511111316763             Baking        BAKING       NaN
# 207        NaN  511111519430             Baking        BAKING     False
# 210        NaN  511111519362             Baking        BAKING     False
# 212        NaN  511111019428             Baking        BAKING     False
# 215        NaN  511111118886             Baking        BAKING     False
# 224        NaN  511111218340             Baking        BAKING     False
# 227        NaN  511111702948                NaN           NaN       NaN
# 229        NaN  511111403630                NaN           NaN       NaN
# 230        NaN  511111301813                NaN           NaN       NaN
# 231        NaN  511111903130                NaN           NaN       NaN
# 233        NaN  511111616696             Baking        BAKING       NaN
# 234             511111301028  Beer Wine Spirits           NaN     False
# 235        NaN  511111115595             Baking        BAKING       NaN
# 236             511111302063            Grocery           NaN     False
# 237        NaN  511111403401                NaN           NaN       NaN
# 240        NaN  511111815891             Baking        BAKING       NaN
# 245        NaN  511111812449          Magazines           NaN      True
# 261        NaN  511111603153                NaN           NaN       NaN
# 269        NaN  511111317920             Baking        BAKING     False
# 272        NaN  511111602996                NaN           NaN       NaN
# 275        NaN  511111202721                NaN           NaN       NaN
# 278             511111801689             Snacks           NaN      True
# 282        NaN  511111903901                NaN           NaN       NaN
#
#                        cpg_id cpg_ref
# 11   5332f5f2e4b03c9a25efd0aa    Cpgs
# 18   5fb28549be37ce522e165cb4    Cogs
# 23   53e10d6368abd3c7065097cc    Cpgs
# 24   5332f5ebe4b03c9a25efd0a8    Cpgs
# 25   5e9f12f5be37ce3e45b6a77e    Cogs
# 29   5f4936dcbe37ce52f8314fd8    Cogs
# 31   5fd2a0aebe37ce49eb72c0ed    Cogs
# 240  5f493665be37ce52f8314fc9    Cogs
# 245  5c4f20b01b4181298aacffc1    Cogs
# 261  53e10d6368abd3c7065097cc    Cpgs
# 269  5fcda47cbe37ce688e08b0c2    Cogs
# 272  5332f5ebe4b03c9a25efd0a8    Cpgs
# 275  5459429be4b0bfcb1e864082    Cpgs
# 278  5332f5fbe4b03c9a25efd0ba    Cogs
# 282  53e10d6368abd3c7065097cc    Cpgs

# %%
brand_duplicate_counts = brands_df.groupby('brand_code').size().reset_index(name='counts')

brand_duplicate_counts = brand_duplicate_counts[brand_duplicate_counts['counts'] > 1]

brand_duplicate_counts['duplicate_records'] = brand_duplicate_counts['counts'] - 1

brand_duplicate_counts[['brand_code', 'duplicate_records']]
# Out:
#     brand_code  duplicate_records
# 0                              34
# 254  GOODNITES                  1
# 277    HUGGIES                  1

# %% [markdown]
# Based on the analysis here, the duplications seem to be majority of 'null' and couple of other brands. On scaling, when we would potentially be adding more brands or when probably other processes populate the values for the nulls we would be in a better position to create data checks. For now it would be best to have them logged for monitoring purposes.

# %% [markdown]
# #### Exploring cpg_id(For data modelling)

# %%
brand_duplicate_counts = brands_df.groupby('cpg_id').size().reset_index(name='counts')

brand_duplicate_counts = brand_duplicate_counts[brand_duplicate_counts['counts'] > 1]

brand_duplicate_counts['duplicate_records'] = brand_duplicate_counts['counts'] - 1

brand_duplicate_counts[['cpg_id', 'duplicate_records']]
# Out:
#                        cpg_id  duplicate_records
# 0    5332f5ebe4b03c9a25efd0a8                 33
# 1    5332f5f2e4b03c9a25efd0aa                 24
# 3    5332f5f3e4b03c9a25efd0ae                 50
# 4    5332f5f6e4b03c9a25efd0b4                 36
# 5    5332f5fbe4b03c9a25efd0ba                 84
# 7    5332f709e4b03c9a25efd0f1                 57
# 10   5332f7a7e4b03c9a25efd134                 26
# 11   5332f7ffe4b03c9a25efd16b                  5
# 12   5332fa12e4b03c9a25efd1e7                 74
# 13   5332fa58e4b03c9a25efd215                  3
# 15   53501d2ab9237fd7718f9e1a                  1
# 17   53e10d6368abd3c7065097cc                 75
# 19   5459429be4b0bfcb1e864082                  3
# 20   550b2565e4b001d5e9e4146f                 11
# 21   559c2234e4b06aca36af13c6                 97
# 25   55b62995e4b0d8e685c14213                 14
# 29   59b96571e4b0bf7c7980588b                  2
# 31   5a734034e4b0d58f376be874                 45
# 32   5c45f8b087ff3552f950f026                  1
# 37   5c76d20595144c5375687b4e                  1
# 39   5d5d4fd16d5f3b23d1bc7905                 40
# 41   5d9b4f591dda2c6225a284aa                 15
# 42   5e28b81cee7f2d697e835bcd                  5
# 43   5e5ea9cc9c50da1291a6d074                  3
# 47   5eebc5412455c97a877ef382                  2
# 49   5f10c05cbe37ce238c6cabaf                  3
# 51   5f16f535be37ce2b30061e24                  3
# 52   5f19e054be37ce33f74a166e                  3
# 54   5f208daebe37ce7958c59520                  3
# 56   5f358338be37ce443bf9d557                  3
# 58   5f35a0babe37ce6853cff1fd                  3
# 177  5ffe35eabe37ce5e01754c45                  3
# 180  5ffe3686be37ce5e01754c5d                  3
# 181  5ffe3a85be37ce7aab2d4fd4                  3
# 184  5fff3aa0be37ce2bb7930116                  3
# 185  6000a0c6be37ce2bb793011c                  3
# 187  6000b8c3be37ce321363c6bf                  3
# 189  60019b82be37ce4f17e558d1                  3
# 192  60074277be37ce360be639fe                  3
# 194  601ac142be37ce2ead437559                  3

# %%
cpg_id_to_check = '5332f5ebe4b03c9a25efd0a8'

json_data_for_cpg_id = [brand for brand in brands_data if 'cpg' in brand and brand['cpg']['$id']['$oid'] 
                        == cpg_id_to_check]

print("JSON Data for cpg_id:", cpg_id_to_check)
print(json.dumps(json_data_for_cpg_id, indent=4))

df_data_for_cpg_id = brands_df[brands_df['cpg_id'] == cpg_id_to_check]

print("DataFrame Data for cpg_id:", cpg_id_to_check)
df_data_for_cpg_id
# Out:
# JSON Data for cpg_id: 5332f5ebe4b03c9a25efd0a8
# [
#     {
#         "_id": {
#             "$oid": "5332fa7ce4b03c9a25efd22e"
#         },
#         "name": "Full Throttle",
#         "cpg": {
#             "$ref": "Cpgs",
#             "$id": {
#                 "$oid": "5332f5ebe4b03c9a25efd0a8"
#             }
#         },
#         "barcode": "511111802914"
#     },
#     {
#         "_id": {
#             "$oid": "5332f765e4b03c9a25efd11f"
#         },
#         "name": "Glaceau vitaminwater",
#         "cpg": {
#             "$ref": "Cpgs",
#             "$id": {
#                 "$oid": "5332f5ebe4b03c9a25efd0a8"
#             }
#         },
#         "barcode": "511111503699"
#     },
#     {
#         "_id": {
#             "$oid": "5332fa7ee4b03c9a25efd230"
#         },
#         "name": "Powerade",
#         "cpg": {
#             "$ref": "Cpgs",
#             "$id": {
#                 "$oid": "5332f5ebe4b03c9a25efd0a8"
#             }
#         },
#         "barcode": "511111702894"
#     },
#     {
#         "_id": {
#             "$oid": "5332f760e4b03c9a25efd11b"
#         },
#         "name": "Honest Ade",
#         "cpg": {
#             "$ref": "Cpgs",
#             "$id": {
#                 "$oid": "5332f5ebe4b03c9a25efd0a8"
#             }
#         },
#         "barcode": "511111603719"
#     },
#     {
#         "_id": {
#             "$oid": "5332fa7ae4b03c9a25efd229"
#         },
#         "name": "Fanta",
#         "cpg": {
#             "$ref": "Cpgs",
#             "$id": {
#                 "$oid": "5332f5ebe4b03c9a25efd0a8"
#             }
#         },
#         "barcode": "511111402961"
#     },
#     {
#         "_id": {
#             "$oid": "5332fa7be4b03c9a25efd22b"
#         },
#         "name": "Diet Cherry Coke",
#         "cpg": {
#             "$ref": "Cpgs",
#             "$id": {
#                 "$oid": "5332f5ebe4b03c9a25efd0a8"
#             }
#         },
#         "barcode": "511111702948"
#     },
#     {
#         "_id": {
#             "$oid": "5332fa79e4b03c9a25efd226"
#         },
#         "name": "Mello Yello",
#         "cpg": {
#             "$ref": "Cpgs",
#             "$id": {
#                 "$oid": "5332f5ebe4b03c9a25efd0a8"
#             }
#         },
#         "barcode": "511111602996"
#     },
#     {
#         "_id": {
#             "$oid": "5332fa73e4b03c9a25efd21c"
#         },
#         "name": "Diet Coke",
#         "cpg": {
#             "$ref": "Cpgs",
#             "$id": {
#                 "$oid": "5332f5ebe4b03c9a25efd0a8"
#             }
#         },
#         "barcode": "511111703051"
#     },
#     {
#         "_id": {
#             "$oid": "5332f753e4b03c9a25efd10f"
#         },
#         "name": "NOS",
#         "cpg": {
#             "$ref": "Cpgs",
#             "$id": {
#                 "$oid": "5332f5ebe4b03c9a25efd0a8"
#             }
#         },
#         "barcode": "511111703778"
#     },
#     {
#         "_id": {
#             "$oid": "5332f760e4b03c9a25efd11a"
#         },
#         "name": "Honest Tea",
#         "cpg": {
#             "$ref": "Cpgs",
#             "$id": {
#                 "$oid": "5332f5ebe4b03c9a25efd0a8"
#             }
#         },
#         "barcode": "511111803720"
#     },
#     {
#         "_id": {
#             "$oid": "5332f5f6e4b03c9a25efd0b2"
#         },
#         "name": "Coca-Cola",
#         "cpg": {
#             "$ref": "Cpgs",
#             "$id": {
#                 "$oid": "5332f5ebe4b03c9a25efd0a8"
#             }
#         },
#         "barcode": "511111703983"
#     },
#     {
#         "_id": {
#             "$oid": "5332f6f4e4b03c9a25efd0ed"
#         },
#         "name": "Peace Tea",
#         "cpg": {
#             "$ref": "Cpgs",
#             "$id": {
#                 "$oid": "5332f5ebe4b03c9a25efd0a8"
#             }
#         },
#         "barcode": "511111103868"
#     },
#     {
#         "_id": {
#             "$oid": "5332fa74e4b03c9a25efd21e"
#         },
#         "name": "Sprite",
#         "cpg": {
#             "$ref": "Cpgs",
#             "$id": {
#                 "$oid": "5332f5ebe4b03c9a25efd0a8"
#             }
#         },
#         "barcode": "511111003038"
#     },
#     {
#         "_id": {
#             "$oid": "5332fa84e4b03c9a25efd232"
#         },
#         "name": "Powerade Zero",
#         "cpg": {
#             "$ref": "Cpgs",
#             "$id": {
#                 "$oid": "5332f5ebe4b03c9a25efd0a8"
#             }
#         },
#         "barcode": "511111002871"
#     },
#     {
#         "_id": {
#             "$oid": "5332f765e4b03c9a25efd120"
#         },
#         "name": "Glaceau fruitwater",
#         "cpg": {
#             "$ref": "Cpgs",
#             "$id": {
#                 "$oid": "5332f5ebe4b03c9a25efd0a8"
#             }
#         },
#         "barcode": "511111003687"
#     },
#     {
#         "_id": {
#             "$oid": "5332fa7be4b03c9a25efd22c"
#         },
#         "name": "Fresca",
#         "cpg": {
#             "$ref": "Cpgs",
#             "$id": {
#                 "$oid": "5332f5ebe4b03c9a25efd0a8"
#             }
#         },
#         "barcode": "511111502937"
#     },
#     {
#         "_id": {
#             "$oid": "5332fa7ce4b03c9a25efd22d"
#         },
#         "name": "Diet Coke Lime",
#         "cpg": {
#             "$ref": "Cpgs",
#             "$id": {
#                 "$oid": "5332f5ebe4b03c9a25efd0a8"
#             }
#         },
#         "barcode": "511111002925"
#     },
#     {
#         "_id": {
#             "$oid": "5332fa7de4b03c9a25efd22f"
#         },
#         "name": "Sprite Zero",
#         "cpg": {
#             "$ref": "Cpgs",
#             "$id": {
#                 "$oid": "5332f5ebe4b03c9a25efd0a8"
#             }
#         },
#         "barcode": "511111302902"
#     },
#     {
#         "_id": {
#             "$oid": "5332f762e4b03c9a25efd11e"
#         },
#         "name": "Glaceau vitaminwater zero",
#         "cpg": {
#             "$ref": "Cpgs",
#             "$id": {
#                 "$oid": "5332f5ebe4b03c9a25efd0a8"
#             }
#         },
#         "barcode": "511111103707"
#     },
#     {
#         "_id": {
#             "$oid": "5332fa7ae4b03c9a25efd228"
#         },
#         "name": "Barq's",
#         "cpg": {
#             "$ref": "Cpgs",
#             "$id": {
#                 "$oid": "5332f5ebe4b03c9a25efd0a8"
#             }
#         },
#         "barcode": "511111902973"
#     },
#     {
#         "_id": {
#             "$oid": "5332fa73e4b03c9a25efd21d"
#         },
#         "name": "Caffeine-free Diet Coke",
#         "cpg": {
#             "$ref": "Cpgs",
#             "$id": {
#                 "$oid": "5332f5ebe4b03c9a25efd0a8"
#             }
#         },
#         "barcode": "511111203049"
#     },
#     {
#         "_id": {
#             "$oid": "5332fa75e4b03c9a25efd220"
#         },
#         "name": "Coca-Cola Zero",
#         "cpg": {
#             "$ref": "Cpgs",
#             "$id": {
#                 "$oid": "5332f5ebe4b03c9a25efd0a8"
#             }
#         },
#         "barcode": "511111503026"
#     },
#     {
#         "_id": {
#             "$oid": "5332fa77e4b03c9a25efd225"
#         },
#         "name": "Cherry Coke",
#         "cpg": {
#             "$ref": "Cpgs",
#             "$id": {
#                 "$oid": "5332f5ebe4b03c9a25efd0a8"
#             }
#         },
#         "barcode": "511111803003"
#     },
#     {
#         "_id": {
#             "$oid": "5332f5ebe4b03c9a25efd0a7"
#         },
#         "name": "Monster",
#         "cpg": {
#             "$ref": "Cpgs",
#             "$id": {
#                 "$oid": "5332f5ebe4b03c9a25efd0a8"
#             }
#         },
#         "barcode": "511111304050"
#     },
#     {
#         "_id": {
#             "$oid": "5332f754e4b03c9a25efd112"
#         },
#         "name": "Fuze",
#         "cpg": {
#             "$ref": "Cpgs",
#             "$id": {
#                 "$oid": "5332f5ebe4b03c9a25efd0a8"
#             }
#         },
#         "barcode": "511111003755"
#     },
#     {
#         "_id": {
#             "$oid": "5332f753e4b03c9a25efd110"
#         },
#         "name": "Sugar Free NOS",
#         "cpg": {
#             "$ref": "Cpgs",
#             "$id": {
#                 "$oid": "5332f5ebe4b03c9a25efd0a8"
#             }
#         },
#         "barcode": "511111203766"
#     },
#     {
#         "_id": {
#             "$oid": "5332f5f5e4b03c9a25efd0b1"
#         },
#         "name": "Minute Maid",
#         "cpg": {
#             "$ref": "Cpgs",
#             "$id": {
#                 "$oid": "5332f5ebe4b03c9a25efd0a8"
#             }
#         },
#         "barcode": "511111203995"
#     },
#     {
#         "_id": {
#             "$oid": "5332fa79e4b03c9a25efd227"
#         },
#         "name": "Caffeine-free Coca-Cola",
#         "cpg": {
#             "$ref": "Cpgs",
#             "$id": {
#                 "$oid": "5332f5ebe4b03c9a25efd0a8"
#             }
#         },
#         "barcode": "511111102984"
#     },
#     {
#         "_id": {
#             "$oid": "5332f73ee4b03c9a25efd108"
#         },
#         "name": "Dr Pepper",
#         "cpg": {
#             "$ref": "Cpgs",
#             "$id": {
#                 "$oid": "5332f5ebe4b03c9a25efd0a8"
#             }
#         },
#         "barcode": "511111403791"
#     },
#     {
#         "_id": {
#             "$oid": "5332fa7ae4b03c9a25efd22a"
#         },
#         "name": "Pibb Xtra",
#         "cpg": {
#             "$ref": "Cpgs",
#             "$id": {
#                 "$oid": "5332f5ebe4b03c9a25efd0a8"
#             }
#         },
#         "barcode": "511111202950"
#     },
#     {
#         "_id": {
#             "$oid": "5332f769e4b03c9a25efd122"
#         },
#         "name": "Odwalla",
#         "cpg": {
#             "$ref": "Cpgs",
#             "$id": {
#                 "$oid": "5332f5ebe4b03c9a25efd0a8"
#             }
#         },
#         "barcode": "511111303664"
#     },
#     {
#         "_id": {
#             "$oid": "5332fa80e4b03c9a25efd231"
#         },
#         "name": "Coca-Cola Cherry Zero",
#         "cpg": {
#             "$ref": "Cpgs",
#             "$id": {
#                 "$oid": "5332f5ebe4b03c9a25efd0a8"
#             }
#         },
#         "barcode": "511111202882"
#     },
#     {
#         "_id": {
#             "$oid": "5332f769e4b03c9a25efd121"
#         },
#         "name": "Glaceau smartwater",
#         "cpg": {
#             "$ref": "Cpgs",
#             "$id": {
#                 "$oid": "5332f5ebe4b03c9a25efd0a8"
#             }
#         },
#         "barcode": "511111803676"
#     },
#     {
#         "_id": {
#             "$oid": "5332fa75e4b03c9a25efd221"
#         },
#         "name": "DASANI",
#         "cpg": {
#             "$ref": "Cpgs",
#             "$id": {
#                 "$oid": "5332f5ebe4b03c9a25efd0a8"
#             }
#         },
#         "barcode": "511111303015"
#     }
# ]
# DataFrame Data for cpg_id: 5332f5ebe4b03c9a25efd0a8
#                       brand_id                 brand_name brand_code  \
# 24    5332fa7ce4b03c9a25efd22e              Full Throttle        NaN
# 43    5332f765e4b03c9a25efd11f       Glaceau vitaminwater        NaN
# 77    5332fa7ee4b03c9a25efd230                   Powerade        NaN
# 147   5332f760e4b03c9a25efd11b                 Honest Ade        NaN
# 195   5332fa7ae4b03c9a25efd229                      Fanta        NaN
# 227   5332fa7be4b03c9a25efd22b           Diet Cherry Coke        NaN
# 272   5332fa79e4b03c9a25efd226                Mello Yello        NaN
# 290   5332fa73e4b03c9a25efd21c                  Diet Coke        NaN
# 350   5332f753e4b03c9a25efd10f                        NOS        NaN
# 387   5332f760e4b03c9a25efd11a                 Honest Tea        NaN
# 484   5332f5f6e4b03c9a25efd0b2                  Coca-Cola        NaN
# 491   5332f6f4e4b03c9a25efd0ed                  Peace Tea        NaN
# 513   5332fa74e4b03c9a25efd21e                     Sprite        NaN
# 525   5332fa84e4b03c9a25efd232              Powerade Zero        NaN
# 562   5332f765e4b03c9a25efd120         Glaceau fruitwater        NaN
# 586   5332fa7be4b03c9a25efd22c                     Fresca        NaN
# 599   5332fa7ce4b03c9a25efd22d             Diet Coke Lime        NaN
# 630   5332fa7de4b03c9a25efd22f                Sprite Zero        NaN
# 643   5332f762e4b03c9a25efd11e  Glaceau vitaminwater zero        NaN
# 708   5332fa7ae4b03c9a25efd228                     Barq's        NaN
# 711   5332fa73e4b03c9a25efd21d    Caffeine-free Diet Coke        NaN
# 784   5332fa75e4b03c9a25efd220             Coca-Cola Zero        NaN
# 808   5332fa77e4b03c9a25efd225                Cherry Coke        NaN
# 852   5332f5ebe4b03c9a25efd0a7                    Monster        NaN
# 935   5332f754e4b03c9a25efd112                       Fuze        NaN
# 959   5332f753e4b03c9a25efd110             Sugar Free NOS        NaN
# 965   5332f5f5e4b03c9a25efd0b1                Minute Maid        NaN
# 972   5332fa79e4b03c9a25efd227    Caffeine-free Coca-Cola        NaN
# 1016  5332f73ee4b03c9a25efd108                  Dr Pepper        NaN
# 1022  5332fa7ae4b03c9a25efd22a                  Pibb Xtra        NaN
# 1041  5332f769e4b03c9a25efd122                    Odwalla        NaN
# 1097  5332fa80e4b03c9a25efd231      Coca-Cola Cherry Zero        NaN
# 1120  5332f769e4b03c9a25efd121         Glaceau smartwater        NaN
# 1157  5332fa75e4b03c9a25efd221                     DASANI        NaN
#
#            barcode category category_code top_brand                    cpg_id  \
# 24    511111802914      NaN           NaN       NaN  5332f5ebe4b03c9a25efd0a8
# 43    511111503699      NaN           NaN       NaN  5332f5ebe4b03c9a25efd0a8
# 77    511111702894      NaN           NaN       NaN  5332f5ebe4b03c9a25efd0a8
# 147   511111603719      NaN           NaN       NaN  5332f5ebe4b03c9a25efd0a8
# 195   511111402961      NaN           NaN       NaN  5332f5ebe4b03c9a25efd0a8
# 227   511111702948      NaN           NaN       NaN  5332f5ebe4b03c9a25efd0a8
# 272   511111602996      NaN           NaN       NaN  5332f5ebe4b03c9a25efd0a8
# 290   511111703051      NaN           NaN       NaN  5332f5ebe4b03c9a25efd0a8
# 350   511111703778      NaN           NaN       NaN  5332f5ebe4b03c9a25efd0a8
# 387   511111803720      NaN           NaN       NaN  5332f5ebe4b03c9a25efd0a8
# 484   511111703983      NaN           NaN       NaN  5332f5ebe4b03c9a25efd0a8
# 491   511111103868      NaN           NaN       NaN  5332f5ebe4b03c9a25efd0a8
# 513   511111003038      NaN           NaN       NaN  5332f5ebe4b03c9a25efd0a8
# 525   511111002871      NaN           NaN       NaN  5332f5ebe4b03c9a25efd0a8
# 562   511111003687      NaN           NaN       NaN  5332f5ebe4b03c9a25efd0a8
# 586   511111502937      NaN           NaN       NaN  5332f5ebe4b03c9a25efd0a8
# 599   511111002925      NaN           NaN       NaN  5332f5ebe4b03c9a25efd0a8
# 630   511111302902      NaN           NaN       NaN  5332f5ebe4b03c9a25efd0a8
# 643   511111103707      NaN           NaN       NaN  5332f5ebe4b03c9a25efd0a8
# 708   511111902973      NaN           NaN       NaN  5332f5ebe4b03c9a25efd0a8
# 711   511111203049      NaN           NaN       NaN  5332f5ebe4b03c9a25efd0a8
# 784   511111503026      NaN           NaN       NaN  5332f5ebe4b03c9a25efd0a8
# 808   511111803003      NaN           NaN       NaN  5332f5ebe4b03c9a25efd0a8
# 852   511111304050      NaN           NaN       NaN  5332f5ebe4b03c9a25efd0a8
# 935   511111003755      NaN           NaN       NaN  5332f5ebe4b03c9a25efd0a8
# 959   511111203766      NaN           NaN       NaN  5332f5ebe4b03c9a25efd0a8
# 965   511111203995      NaN           NaN       NaN  5332f5ebe4b03c9a25efd0a8
# 972   511111102984      NaN           NaN       NaN  5332f5ebe4b03c9a25efd0a8
# 1016  511111403791      NaN           NaN       NaN  5332f5ebe4b03c9a25efd0a8
# 1022  511111202950      NaN           NaN       NaN  5332f5ebe4b03c9a25efd0a8
# 1041  511111303664      NaN           NaN       NaN  5332f5ebe4b03c9a25efd0a8
# 1097  511111202882      NaN           NaN       NaN  5332f5ebe4b03c9a25efd0a8
# 1120  511111803676      NaN           NaN       NaN  5332f5ebe4b03c9a25efd0a8
# 1157  511111303015      NaN           NaN       NaN  5332f5ebe4b03c9a25efd0a8
#
#      cpg_ref
# 24      Cpgs
# 43      Cpgs
# 77      Cpgs
# 147     Cpgs
# 195     Cpgs
# 227     Cpgs
# 272     Cpgs
# 290     Cpgs
# 350     Cpgs
# 387     Cpgs
# 484     Cpgs
# 491     Cpgs
# 513     Cpgs
# 525     Cpgs
# 562     Cpgs
# 586     Cpgs
# 599     Cpgs
# 630     Cpgs
# 643     Cpgs
# 708     Cpgs
# 711     Cpgs
# 784     Cpgs
# 808     Cpgs
# 852     Cpgs
# 935     Cpgs
# 959     Cpgs
# 965     Cpgs
# 972     Cpgs
# 1016    Cpgs
# 1022    Cpgs
# 1041    Cpgs
# 1097    Cpgs
# 1120    Cpgs
# 1157    Cpgs

# %% [markdown]
# Seems like cpg_id corresponds roughly to 'catgeory' of the product and could be usefull for any future requirements from the stakeholders. A cpg table would be a good idea for expansion.

# %% [markdown]
# ### Reciepts data checks

# %%
receipts_only_df.isna().sum()
# Out:
# receipt_id                      0
# user_id                         0
# bonus_points_earned           575
# bonus_points_earned_reason    575
# create_date                     0
# date_scanned                    0
# finished_date                 551
# modify_date                     0
# points_awarded_date           582
# points_earned                 510
# purchase_date                 448
# purchased_item_count          484
# rewards_receipt_status          0
# total_spent                   435
# dtype: int64

# %%
print(receipts_only_df.dtypes)
# Out:
# receipt_id                            object
# user_id                               object
# bonus_points_earned                  float64
# bonus_points_earned_reason            object
# create_date                   datetime64[ns]
# date_scanned                  datetime64[ns]
# finished_date                 datetime64[ns]
# modify_date                   datetime64[ns]
# points_awarded_date           datetime64[ns]
# points_earned                         object
# purchase_date                 datetime64[ns]
# purchased_item_count                 float64
# rewards_receipt_status                object
# total_spent                           object
# dtype: object

# %% [markdown]
# #### Checking for duplicate receipt_id's

# %%
receipts_duplicate_record = receipts_only_df[receipts_only_df.duplicated('receipt_id')]

print("Duplicated Records:")
receipts_duplicate_record.head(70)
# Out:
# Duplicated Records:
# Empty DataFrame
# Columns: [receipt_id, user_id, bonus_points_earned, bonus_points_earned_reason, create_date, date_scanned, finished_date, modify_date, points_awarded_date, points_earned, purchase_date, purchased_item_count, rewards_receipt_status, total_spent]
# Index: []

# %% [markdown]
# #### Checking for rewards status

# %%
receipts_only_df['rewards_receipt_status'].unique()
# Out:
# array(['FINISHED', 'REJECTED', 'FLAGGED', 'SUBMITTED', 'PENDING'],
#       dtype=object)

# %% [markdown]
# #### Checking purchase_date is earlier than create_date

# %%
purchase_date_anamoly_df = receipts_only_df[(receipts_only_df['purchase_date'] > receipts_only_df['create_date'])]

print("Rows where create_date is older than purchase_date:")
purchase_date_anamoly_df[['receipt_id', 'purchase_date', 'create_date']]
# Out:
# Rows where create_date is older than purchase_date:
#                    receipt_id       purchase_date         create_date
# 12   5ff1e1b60a7214ada100055c 2021-02-03 15:24:38 2021-01-03 15:24:38
# 14   5ff1e1b20a7214ada100055a 2021-02-03 15:24:35 2021-01-03 15:24:34
# 85   5ff4ce640a7214ada10005e0 2021-02-05 20:39:00 2021-01-05 20:39:00
# 139  5ff73be10a7214ada1000619 2021-02-07 16:50:41 2021-01-07 16:50:41
# 158  5ff873f10a720f052300064f 2021-02-08 15:02:10 2021-01-08 15:02:09
# 190  5ffcb4900a720f0515000002 2021-02-11 20:26:56 2021-01-11 20:26:56
# 244  5fff26ee0a720f05f300001a 2021-02-13 16:59:26 2021-01-13 16:59:26
# 265  5fff26f10a7214ad4c000018 2021-02-13 16:59:29 2021-01-13 16:59:29
# 294  6000d4bc0a7214ad4c000070 2021-02-14 23:33:17 2021-01-14 23:33:16
# 362  600887560a720f05fa000098 2021-02-20 19:41:10 2021-01-20 19:41:10
# 553  60145a3d0a7214ad50000082 2021-02-28 18:55:58 2021-01-29 18:55:57
# 644  60182f290a720f05f800032f 2021-03-01 16:41:13 2021-02-01 16:41:13
# 871  602176c90a7214d8e9000028 2021-03-08 17:37:13 2021-02-08 17:37:13

# %%
len(purchase_date_anamoly_df)
# Out:
# 13

# %% [markdown]
# Given that there are 13 cases where the purchase date is after the create date there needs to be checks in place to handle this or if there is a business logic that explains this anamoly

# %% [markdown]
# ### Receipt items data check

# %%
items_df.isna().sum()
# Out:
# barcode                               3851
# description                            381
# finalPrice                             174
# itemPrice                              174
# needsFetchReview                      6128
# partnerItemId                            0
# preventTargetGapPoints                6583
# quantityPurchased                      174
# userFlaggedBarcode                    6604
# userFlaggedNewItem                    6618
# userFlaggedPrice                      6642
# userFlaggedQuantity                   6642
# receipt_id                               0
# needsFetchReviewReason                6722
# pointsNotAwardedReason                6601
# pointsPayerId                         5674
# rewardsGroup                          5210
# rewardsProductPartnerId               4672
# userFlaggedDescription                6736
# originalMetaBriteBarcode              6870
# originalMetaBriteDescription          6931
# brandCode                             4341
# competitorRewardsGroup                6666
# discountedItemPrice                   1172
# originalReceiptItemText               1181
# itemNumber                            6788
# originalMetaBriteQuantityPurchased    6926
# pointsEarned                          6014
# targetPrice                           6563
# competitiveProduct                    6296
# originalFinalPrice                    6932
# originalMetaBriteItemPrice            6932
# deleted                               6932
# priceAfterCoupon                      5985
# metabriteCampaignId                   6078
# dtype: int64

# %%
print(items_df.dtypes)
# Out:
# barcode                                object
# description                            object
# finalPrice                             object
# itemPrice                              object
# needsFetchReview                       object
# partnerItemId                          object
# preventTargetGapPoints                 object
# quantityPurchased                     float64
# userFlaggedBarcode                     object
# userFlaggedNewItem                     object
# userFlaggedPrice                       object
# userFlaggedQuantity                   float64
# receipt_id                             object
# needsFetchReviewReason                 object
# pointsNotAwardedReason                 object
# pointsPayerId                          object
# rewardsGroup                           object
# rewardsProductPartnerId                object
# userFlaggedDescription                 object
# originalMetaBriteBarcode               object
# originalMetaBriteDescription           object
# brandCode                              object
# competitorRewardsGroup                 object
# discountedItemPrice                    object
# originalReceiptItemText                object
# itemNumber                             object
# originalMetaBriteQuantityPurchased    float64
# pointsEarned                           object
# targetPrice                            object
# competitiveProduct                     object
# originalFinalPrice                     object
# originalMetaBriteItemPrice             object
# deleted                                object
# priceAfterCoupon                       object
# metabriteCampaignId                    object
# dtype: object

# %% [markdown]
# #### Updating the data types for numerical columns

# %%
items_df['finalPrice'] = items_df['finalPrice'].astype('float')
items_df['itemPrice'] = items_df['itemPrice'].astype('float')
items_df['userFlaggedQuantity'] = items_df['userFlaggedQuantity'].astype('float')
items_df['originalMetaBriteQuantityPurchased'] = items_df['originalMetaBriteQuantityPurchased'].astype('float')
items_df['pointsEarned'] = items_df['pointsEarned'].astype('float')
items_df['targetPrice'] = items_df['targetPrice'].astype('float')
items_df['originalFinalPrice'] = items_df['originalFinalPrice'].astype('float')
items_df['originalMetaBriteItemPrice'] = items_df['originalMetaBriteItemPrice'].astype('float')
items_df['priceAfterCoupon'] = items_df['priceAfterCoupon'].astype('float')

# %%
print(items_df.dtypes)
# Out:
# barcode                                object
# description                            object
# finalPrice                            float64
# itemPrice                             float64
# needsFetchReview                       object
# partnerItemId                          object
# preventTargetGapPoints                 object
# quantityPurchased                     float64
# userFlaggedBarcode                     object
# userFlaggedNewItem                     object
# userFlaggedPrice                       object
# userFlaggedQuantity                   float64
# receipt_id                             object
# needsFetchReviewReason                 object
# pointsNotAwardedReason                 object
# pointsPayerId                          object
# rewardsGroup                           object
# rewardsProductPartnerId                object
# userFlaggedDescription                 object
# originalMetaBriteBarcode               object
# originalMetaBriteDescription           object
# brandCode                              object
# competitorRewardsGroup                 object
# discountedItemPrice                    object
# originalReceiptItemText                object
# itemNumber                             object
# originalMetaBriteQuantityPurchased    float64
# pointsEarned                          float64
# targetPrice                           float64
# competitiveProduct                     object
# originalFinalPrice                    float64
# originalMetaBriteItemPrice            float64
# deleted                                object
# priceAfterCoupon                      float64
# metabriteCampaignId                    object
# dtype: object

# %% [markdown]
# #### Checking if the columns 'quantityPurchased' and 'finalPrice' are negative

# %%
invalid_items_df = items_df[(items_df['quantityPurchased'] < 0) & (items_df['finalPrice'] < 0)]

print("Rows with negative quantityPurchased and finalPrice:")
invalid_items_df[['receipt_id', 'quantityPurchased', 'finalPrice']].head(70)
# Out:
# Rows with negative quantityPurchased and finalPrice:
# Empty DataFrame
# Columns: [receipt_id, quantityPurchased, finalPrice]
# Index: []

# %% [markdown]
# #### Find common barcodes between items and brands dataframes

# %%
items_barcode = set(items_df['barcode'])
brands_barcode = set(brands_df['barcode'])

known_brands = items_barcode.intersection(brands_barcode)
known_brands
# Out:
# {'511111001485',
#  '511111001768',
#  '511111003960',
#  '511111004127',
#  '511111101451',
#  '511111104186',
#  '511111104537',
#  '511111204206',
#  '511111502142',
#  '511111518044',
#  '511111602118',
#  '511111704140',
#  '511111802358',
#  '511111901587',
#  '511111902690',
#  '511111904175'}

# %%
len(known_brands)
# Out:
# 16

# %% [markdown]
# #### Find common brand codes between items and brands dataframes

# %%
items_brandcode = set(items_df['brandCode'])
brands_barcode = set(brands_df['brand_code'])

known_brands_codes = items_brandcode.intersection(brands_barcode)
known_brands_codes
# Out:
# {'ARNOLD',
#  'CHEETOS',
#  'CLASSICO',
#  'COOL WHIP',
#  'COTTONELLE',
#  'CRACKER BARREL',
#  'DOLE CHILLED FRUIT JUICES',
#  'DORITOS',
#  'FINISH',
#  'GREY POUPON',
#  "HELLMANN'S/BEST FOODS",
#  'HUGGIES',
#  'JELL-O',
#  'JUST CRACK AN EGG',
#  'KETTLE BRAND',
#  'KLEENEX',
#  'KLONDIKE',
#  'KNORR',
#  'KRAFT',
#  'LUNCHABLES',
#  'MOUNTAIN DEW',
#  'NATURE VALLEY',
#  'ORE-IDA',
#  'OSCAR MAYER',
#  'PACIFIC FOODS',
#  'PEPPERIDGE FARM',
#  'PEPSI',
#  'PHILADELPHIA',
#  'PLANTERS',
#  'PREGO',
#  'QUAKER',
#  'RICE-A-RONI',
#  'SARGENTO',
#  'STOVE TOP',
#  'SWANSON',
#  'TACO BELL',
#  'TOSTITOS',
#  'V8',
#  'VELVEETA',
#  'VIVA',
#  'YUBAN',
#  nan}

# %%
len(known_brands_codes)
# Out:
# 42
